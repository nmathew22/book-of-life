# %%
# Mount Google Drive
from google.colab import drive
import os
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Change directory
# %%capture
# %cd drive/MyDrive/Sophomore\ Year/Fall/MGT802/final_project/repo

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Sophomore Year/Fall/MGT802/final_project/repo

# %%
# Installing langchain and old openapi version
# %%capture
# !pip install langchain
# !pip install  "openai<=0.28.1"

# %%
# Importing OpenAI API Key and previously installed libraries
import credentials
import os
import openai
import textwrap
openai.api_key = credentials.OPENAI_API_KEY
os.environ["OPENAI_API_KEY"] = credentials.OPENAI_API_KEY
apikey = credentials.OPENAI_API_KEY

# %%
# Importing langchain packages
from langchain.llms import OpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain, SequentialChain

# %%
# %%capture
# !pip install streamlit

# %%
# %%capture
# !npm install localtunnel

# %%
! wget -q -O - ipv4.icanhazip.com
# Out:
# 34.125.55.110

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
! npx localtunnel --port 8501
# Out:
# npx: installed 22 in 3.002s
# your url is: https://upset-breads-turn.loca.lt
# ^C
